# %% [markdown]
# ### Data Transformation & Engineering: Structuring JSON Event Data for Company XYZ

# %% [markdown]
# ***This project focuses on transforming unstructured JSON event data into structured CSV tables for improved accessibility and analysis within Company XYZ. The dataset originates from app-generated events and backend APIs, requiring data engineering processes to ensure data quality and usability. The objective is to convert the provided case.json file into three structured CSV files—CuratedOfferOptions.csv, DynamicPriceOption.csv, and DynamicPriceRange.csv—by extracting and formatting key attributes according to predefined rules. The transformation process prioritizes data integrity, efficient structuring, and localization (UTC-3 conversion for timestamps). This project demonstrates the ability to process real-world event data, enhancing data-driven decision-making for business growth.***

# %% [markdown]
# The company receives event data in JSON format, which requires transformation into structured tables for better analysis and accessibility. The task is to process the provided case.json file and convert it into three CSV files—CuratedOfferOptions.csv, DynamicPriceOption.csv, and DynamicPriceRange.csv—following these specific formatting guidelines:
#
# 1. **CuratedOfferOptions.csv:**
# - CurationProvider, OfferId, DealerId, UniqueOptionId, OptionId, Eta, ProductBrand, DefeatPrimaryReason, DefeatReasons: Enclosed in quotes
# - IsMobileDealer, IsOpen, ChamaScore, IsWinner, MinimumPrice, MaximumPrice, DynamicPrice, FinalPrice: Without quotes
# - EnqueuedTimeSP: Formatted as DD/MM/YYYY, converted to Brazilian time zone (UTC-3
#
# 2. **DynamicPriceOption.csv:**
# - Provider, OfferId, UniqueOptionId: Enclosed in quotes
# - BestPrice: Without quotes
# - EnqueuedTimeSP: Formatted as DD/MM/YYYY, converted to Brazilian time zone (UTC-3)
#
#
# 3. **DynamicPriceRange.csv:**
# - Provider, OfferId: Enclosed in quotes
# - MinGlobal, MinRecommended, MaxRecommended, DifferenceMinRecommendMinTheory: Without quotes
# - EnqueuedTimeSP: Formatted as DD/MM/YYYY, converted to Brazilian time zone (UTC-3)
#
#
# ***This transformation ensures that the event data is structured in a standardized format, improving usability for data analysis and decision-making within the company.***

# %% [markdown]
# ### **0. Data Exploration**

# %% [markdown]
# Before proceeding with the data transformation, this section focuses on exploring and understanding the provided data. Gaining familiarity with the dataset will help us better grasp the challenges faced by the company and develop an effective solution.

# %%
import pandas as pd

# %%
df = pd.read_json(path_or_buf="case.json")

# %%
df.sample(n=10, random_state=42)
# Out:
#             EnqueuedTimeUtc            EventName  \
# 17  2021-08-25 09:02:29 UTC   CurateOffer_Result
# 13  2021-08-25 09:03:29 UTC   CurateOffer_Result
# 4   2021-09-05 08:03:28 UTC  DynamicPrice_Result
# 29  2021-09-05 09:04:17 UTC  DynamicPrice_Result
# 35  2021-08-25 09:03:14 UTC   CurateOffer_Result
# 25  2021-09-05 09:02:05 UTC  DynamicPrice_Result
# 6   2021-09-05 08:03:40 UTC  DynamicPrice_Result
# 26  2021-09-05 09:17:21 UTC  DynamicPrice_Result
# 24  2021-09-05 04:04:05 UTC  DynamicPrice_Result
# 16  2021-09-05 08:03:00 UTC  DynamicPrice_Result
#
#                                               Payload
# 17  [{"curationProvider":"ByPrice","offerId":"0a06...
# 13  [{"curationProvider":"ByPrice","offerId":"c99a...
# 4   {"provider":"ApplyDynamicPriceRange","offerId"...
# 29  {"provider":"ApplyDynamicPriceRange","offerId"...
# 35  [{"curationProvider":"ByPrice","offerId":"135d...
# 25  {"provider":"ApplyDynamicPriceRange","offerId"...
# ...

# %%
df.shape
# Out:
# (37, 3)

# %% [markdown]
# ***The DataFrame contains 37 rows and three columns:***
#
# EnqueuedTimeUTC – The timestamp indicating when the event occurred (UTC timezone).
# EventName – The name of the recorded event.
# Payload – Event-specific details stored as additional information.
# A key observation from the sample data is that different EventName values correspond to the required CSV outputs. This suggests that partitioning the DataFrame based on the EventName column will be necessary.
#
# Before proceeding with partitioning and generating the CSV files, it may be beneficial to first convert the timestamps to the appropriate timezone.

# %%
df.head()
# Out:
#            EnqueuedTimeUtc            EventName  \
# 0  2021-09-05 08:04:08 UTC  DynamicPrice_Result
# 1  2021-08-18 11:43:23 UTC  DynamicPrice_Result
# 2  2021-09-05 09:04:04 UTC  DynamicPrice_Result
# 3  2021-08-25 05:02:55 UTC   CurateOffer_Result
# 4  2021-09-05 08:03:28 UTC  DynamicPrice_Result
#
#                                              Payload
# 0  {"provider":"ApplyDynamicPriceRange","offerId"...
# 1  {"provider":"ApplyDynamicPricePerOption","offe...
# 2  {"provider":"ApplyDynamicPriceRange","offerId"...
# 3  [{"curationProvider":"ByPrice","offerId":"149f...
# 4  {"provider":"ApplyDynamicPriceRange","offerId"...

# %%
# transform to Brazilian timezone
df["EnqueuedTimeUtc"] = pd.to_datetime(arg=df["EnqueuedTimeUtc"]).dt.tz_convert(tz="Brazil/East")

# %%
df.head()
# Out:
#             EnqueuedTimeUtc            EventName  \
# 0 2021-09-05 05:04:08-03:00  DynamicPrice_Result
# 1 2021-08-18 08:43:23-03:00  DynamicPrice_Result
# 2 2021-09-05 06:04:04-03:00  DynamicPrice_Result
# 3 2021-08-25 02:02:55-03:00   CurateOffer_Result
# 4 2021-09-05 05:03:28-03:00  DynamicPrice_Result
#
#                                              Payload
# 0  {"provider":"ApplyDynamicPriceRange","offerId"...
# 1  {"provider":"ApplyDynamicPricePerOption","offe...
# 2  {"provider":"ApplyDynamicPriceRange","offerId"...
# 3  [{"curationProvider":"ByPrice","offerId":"149f...
# 4  {"provider":"ApplyDynamicPriceRange","offerId"...

# %%
df["EventName"].value_counts()
# Out:
# EventName
# DynamicPrice_Result    32
# CurateOffer_Result      5
# Name: count, dtype: int64

# %% [markdown]
# Our dataset contains two distinct events: DynamicPrice_Result and CuratedOffer_Result.
#
# Rows with DynamicPrice_Result will be used to generate the second and third CSV files.
# Rows with CuratedOffer_Result will be used to generate the first CSV file.
# We will begin by processing the dynamic pricing CSVs first.

# %% [markdown]
# ### **1. DynamicPriceOption**

# %%
dynamic_price_events = df[df["EventName"] == "DynamicPrice_Result"]
dynamic_price_events.shape
# Out:
# (32, 3)

# %%
dynamic_price_events.head()
# Out:
#             EnqueuedTimeUtc            EventName  \
# 0 2021-09-05 05:04:08-03:00  DynamicPrice_Result
# 1 2021-08-18 08:43:23-03:00  DynamicPrice_Result
# 2 2021-09-05 06:04:04-03:00  DynamicPrice_Result
# 4 2021-09-05 05:03:28-03:00  DynamicPrice_Result
# 5 2021-08-18 08:44:00-03:00  DynamicPrice_Result
#
#                                              Payload
# 0  {"provider":"ApplyDynamicPriceRange","offerId"...
# 1  {"provider":"ApplyDynamicPricePerOption","offe...
# 2  {"provider":"ApplyDynamicPriceRange","offerId"...
# 4  {"provider":"ApplyDynamicPriceRange","offerId"...
# 5  {"provider":"ApplyDynamicPricePerOption","offe...

# %% [markdown]
# To execute the transformation, we will apply a **custom function** to each row in the relevant DataFrame. Take a moment to review the **dynamic_price_option** function to understand its logic.
#
# Additionally, to gain better insight into the **Payload** structure, we recommend printing its contents at different levels. For this event type, the **Payload** includes:
# - A **provider** and **offer ID** at the top level.
# - A nested **algorithmOutput** structure containing event-specific fields.

# %%
import json


def dynamic_price_option(row):
    """Transform the JSON payload into a dynamic price option dataframe."""
    enqueued_time = row["EnqueuedTimeUtc"].to_pydatetime().strftime("%d/%m/%y")
    payload_row = row["Payload"]
    payload_row = json.loads(payload_row)
    result = []
    if payload_row["provider"] == "ApplyDynamicPricePerOption":
        provider = f"\"{payload_row['provider']}\""
        offer_id = f"\"{payload_row['offerId']}\""
        for unique_option in payload_row["algorithmOutput"]:
            price_option = {
                "Provider": provider,
                "OfferId": offer_id,
                "UniqueOptionId": f"\"{unique_option['uniqueOptionId']}\"",
                "BestPrice": unique_option["bestPrice"],
                "EnqueuedTimeSP": enqueued_time
            }
            result.append(price_option)
    return result


lst = dynamic_price_events.apply(dynamic_price_option, axis=1)
flatten = [x for xs in lst for x in xs]
dynamic_price_option_payload = pd.DataFrame(flatten)

# %%
dynamic_price_option_payload
# Out:
#                         Provider                                 OfferId  \
# 0   "ApplyDynamicPricePerOption"  "56e0702c-0218-4626-8d3d-ae9d54b4503b"
# 1   "ApplyDynamicPricePerOption"  "56e0702c-0218-4626-8d3d-ae9d54b4503b"
# 2   "ApplyDynamicPricePerOption"  "56e0702c-0218-4626-8d3d-ae9d54b4503b"
# 3   "ApplyDynamicPricePerOption"  "56e0702c-0218-4626-8d3d-ae9d54b4503b"
# 4   "ApplyDynamicPricePerOption"  "56e0702c-0218-4626-8d3d-ae9d54b4503b"
# 5   "ApplyDynamicPricePerOption"  "56e0702c-0218-4626-8d3d-ae9d54b4503b"
# 6   "ApplyDynamicPricePerOption"  "56e0702c-0218-4626-8d3d-ae9d54b4503b"
# 7   "ApplyDynamicPricePerOption"  "56e0702c-0218-4626-8d3d-ae9d54b4503b"
# 8   "ApplyDynamicPricePerOption"  "00991873-194e-4a6e-89c9-8f68668b6aaa"
# 9   "ApplyDynamicPricePerOption"  "00991873-194e-4a6e-89c9-8f68668b6aaa"
# 10  "ApplyDynamicPricePerOption"  "00991873-194e-4a6e-89c9-8f68668b6aaa"
# 11  "ApplyDynamicPricePerOption"  "00991873-194e-4a6e-89c9-8f68668b6aaa"
# ...

# %% [markdown]
# ***We can confirm that the output is as expected, so we save the DataFrame as a CSV.***

# %%
dynamic_price_option_payload.to_csv("dynamic_price_option_payload.csv", index=False)

# %% [markdown]
# ### **2. DynamicPriceRange**

# %%
def dynamic_price_range(row):
    """Transform the JSON payload into a dynamic price range dataframe."""
    enqueued_time = row["EnqueuedTimeUtc"].to_pydatetime().strftime("%d/%m/%y")
    payload_row = row["Payload"]
    payload_row = json.loads(payload_row)
    result = []
    if payload_row["provider"] == "ApplyDynamicPriceRange":
        provider = f"\"{payload_row['provider']}\""
        offer_id = f"\"{payload_row['offerId']}\""
        algorithm_output = payload_row["algorithmOutput"]
        price_range = {
            "Provider": provider,
            "OfferId": offer_id,
            "MinGlobal": algorithm_output["min_global"],
            "MinRecommended": algorithm_output["min_recommended"],
            "MaxRecommended": algorithm_output["max_recommended"],
            "DifferenceMinRecommendMinTheory": algorithm_output["differenceMinRecommendMinTheory"],
            "EnqueuedTimeSP": enqueued_time
        }
        result.append(price_range)
    return result


lst = dynamic_price_events.apply(dynamic_price_range, axis=1)
flatten = [x for xs in lst for x in xs]
dynamic_price_range_payload = pd.DataFrame(flatten)

# %%
dynamic_price_range_payload
# Out:
#                     Provider                                 OfferId  \
# 0   "ApplyDynamicPriceRange"  "a6611d55-9624-4381-8cdd-323ee3689241"
# 1   "ApplyDynamicPriceRange"  "b8c636fa-8241-47dc-ac40-bdf438a04d9c"
# 2   "ApplyDynamicPriceRange"  "3d32f7fb-396d-4d3f-b673-dea1f7dc41b7"
# 3   "ApplyDynamicPriceRange"  "329194f3-95a4-45ef-b3d0-2796f74ce2a0"
# 4   "ApplyDynamicPriceRange"  "fdcfde5c-113d-4a59-9ae0-8bc31e2943d8"
# 5   "ApplyDynamicPriceRange"  "27bbc4fa-2388-4780-b66c-92a51397d191"
# 6   "ApplyDynamicPriceRange"  "baffc30b-7642-45fe-a2ce-da31a71732ae"
# 7   "ApplyDynamicPriceRange"  "b5982abd-f602-47ac-b45a-bb43bf993d46"
# 8   "ApplyDynamicPriceRange"  "f6643886-4a0f-45ae-ae32-ee95c72ee94a"
# 9   "ApplyDynamicPriceRange"  "16a2d492-b1c3-40ec-970f-b8704d8db96f"
# 10  "ApplyDynamicPriceRange"  "e94cf567-d77a-4874-9663-0b49d19f604c"
# 11  "ApplyDynamicPriceRange"  "57a52d66-93fb-40a4-b44a-662d439ce070"
# 12  "ApplyDynamicPriceRange"  "0474ba06-1a1e-4ebe-934f-b416dd0c9313"
# ...

# %% [markdown]
# ***Upon the visual confirmation that the result is correct, we store the DataFrame as CSV.***

# %%
dynamic_price_range_payload.to_csv("dynamic_price_range_payload.csv", index=False)

# %% [markdown]
# ### **3. CurratedOfferOptions**

# %% [markdown]
# Let's first filter the curated offers from the main data set. We see that there are only five such events.

# %%
curated_offers = df[df["EventName"] == "CurateOffer_Result"]
curated_offers.shape
# Out:
# (5, 3)

# %%
curated_offers.head()
# Out:
#              EnqueuedTimeUtc           EventName  \
# 3  2021-08-25 02:02:55-03:00  CurateOffer_Result
# 13 2021-08-25 06:03:29-03:00  CurateOffer_Result
# 15 2021-08-25 02:02:18-03:00  CurateOffer_Result
# 17 2021-08-25 06:02:29-03:00  CurateOffer_Result
# 35 2021-08-25 06:03:14-03:00  CurateOffer_Result
#
#                                               Payload
# 3   [{"curationProvider":"ByPrice","offerId":"149f...
# 13  [{"curationProvider":"ByPrice","offerId":"c99a...
# 15  [{"curationProvider":"ByPrice","offerId":"d668...
# 17  [{"curationProvider":"ByPrice","offerId":"0a06...
# 35  [{"curationProvider":"ByPrice","offerId":"135d...

# %%
def curated_offer(row):
    """Transform JSON payload into curated offer dataframe."""
    enqueued_time = row["EnqueuedTimeUtc"].to_pydatetime().strftime("%d/%m/%y")
    payload_row = row["Payload"]
    payload_row = json.loads(payload_row)
    result = []
    for el in payload_row:
        curation_provider = f"\"{el['curationProvider']}\""
        offer_id = f"\"{el['offerId']}\""
        dealer_id = f"\"{el['dealerId']}\""
        for option in el["options"]:
            offer_options = {
                "CurationProvider": curation_provider,
                "OfferId": offer_id,
                "DealerId": dealer_id,
                "UniqueOptionId": f"\"{option['uniqueOptionId']}\"",
                "OptionId": f"\"{option['optionId']}\"",
                "IsMobileDealer": option["isMobileDealer"],
                "IsOpen": option["isOpen"],
                "Eta": f"\"{option['eta']}\"",
                "ChamaScore": option["chamaScore"],
                "ProductBrand": f"\"{option['productBrand']}\"",
                "IsWinner": option["isWinner"],
                "MinimumPrice": option["minimumPrice"],
                "MaximumPrice": option["maximumPrice"],
                "DynamicPrice": option["dynamicPrice"],
                "FinalPrice": option["finalPrice"]
            }
            if "defeatPrimaryReason" in option:
                offer_options["DefeatPrimaryReason"] = f"\"{option['defeatPrimaryReason']}\""
                offer_options["DefeatReasons"] = f"\"{option['defeatReasons']}\""
            else:
                offer_options["DefeatPrimaryReason"] = "\"\""
                offer_options["DefeatReasons"] = "\"\""
            offer_options["EnqueuedTimeSP"] = enqueued_time
            result.append(offer_options)
    return result


flatten = [x for xs in curated_offers.apply(curated_offer, axis=1) for x in xs]
curated_offers_payload = pd.DataFrame(flatten)

# %%
curated_offers_payload
# Out:
#    CurationProvider                                 OfferId DealerId  \
# 0         "ByPrice"  "149f0e53-ff85-425f-a01a-8710f06704ea"   "6517"
# 1         "ByPrice"  "149f0e53-ff85-425f-a01a-8710f06704ea"   "6517"
# 2         "ByPrice"  "149f0e53-ff85-425f-a01a-8710f06704ea"   "9047"
# 3         "ByPrice"  "149f0e53-ff85-425f-a01a-8710f06704ea"   "9047"
# 4         "ByPrice"  "149f0e53-ff85-425f-a01a-8710f06704ea"   "9047"
# 5         "ByPrice"  "149f0e53-ff85-425f-a01a-8710f06704ea"   "9047"
# 6         "ByPrice"  "149f0e53-ff85-425f-a01a-8710f06704ea"   "8330"
# 7         "ByPrice"  "149f0e53-ff85-425f-a01a-8710f06704ea"   "8835"
# 8         "ByPrice"  "c99aa9a7-ac50-4a10-be0f-ac9f5ac0f45d"   "6517"
# 9         "ByPrice"  "c99aa9a7-ac50-4a10-be0f-ac9f5ac0f45d"   "6517"
# 10        "ByPrice"  "c99aa9a7-ac50-4a10-be0f-ac9f5ac0f45d"   "9047"
# 11        "ByPrice"  "c99aa9a7-ac50-4a10-be0f-ac9f5ac0f45d"   "9047"
# 12        "ByPrice"  "c99aa9a7-ac50-4a10-be0f-ac9f5ac0f45d"   "9047"
# ...

# %% [markdown]
# Similarly, as with the previous files, we visually inspect the output, and if the transformation seems correct, we can save it to CSV format.

# %%
curated_offers_payload.to_csv("curated_offers_payload.csv", index=False)
